# %% [markdown]
# <a href="https://colab.research.google.com/github/Stronglight0627/PilGi/blob/main/%EA%B2%BD%EC%82%AC%ED%95%98%EA%B0%95%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

data = [[2,0,81],[4,4,93],[6,4,91],[8,3,97]]
x1 = [i[0] for i in data]
x2 = [i[1] for i in data]
y = [i[2] for i in data]

ax = plt.axes(projection='3d')
ax.set_xlabel('s_h')
ax.set_xlabel('p')
ax.set_xlabel('sc')
ax.dist=11
ax.scatter(x1,x2,y)
plt.show()

# plt.figure(figsize = (8,5))
# plt.scatter(x,y)
# plt.show()

x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)
a1=0
a2=0
b1=0
lr = 0.05
epochs = 2001

# for i in range(epochs):
#   y_pred = a* x_data + b
#   error = y_data - y_pred
#   a_diff =-(1/len(x_data)) * sum(x_data * (error))
#   b_diff =-(1/len(x_data)) * sum(y_data - y_pred)
#   a = a - lr * a_diff
#   b = b - lr * b_diff

#   

# y_pred = a * x_data + b
# plt.scatter(x, y)
# plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
# plt.show()

for i in range(epochs):
  y_pred = a1 * x1_data  + a2 * x2_data + b1
  error = y_data - y_pred
  a1_diff =-(1/len(x1_data)) * sum(x1_data * (error))
  a2_diff =-(1/len(x2_data)) * sum(x2_data * (error))
  b_diff =-(1/len(x1_data)) * sum(y_data - y_pred)
  a1 = a1 - lr * a1_diff
  a2 = a2 - lr * a2_diff
  b = b - lr * b_diff
  if i % 100 == 0:
    print('epochs = %.f, 기울기1 = %.04f, 기울기2 = %.04f, 절편 = %.04f' % (i, a1, a2, b))
# Out:
# epochs = 0, 기울기1 = 23.2000, 기울기2 = 12.8375, 절편 = 83.5250
# epochs = 100, 기울기1 = 12.6272, 기울기2 = 5.4343, 절편 = 145.2573
# epochs = 200, 기울기1 = 12.5827, 기울기2 = 5.4079, 절편 = 208.8299
# epochs = 300, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 272.4099
# epochs = 400, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 335.9900
# epochs = 500, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 399.5701
# epochs = 600, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 463.1502
# epochs = 700, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 526.7303
# epochs = 800, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 590.3104
# epochs = 900, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 653.8905
# epochs = 1000, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 717.4706
# epochs = 1100, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 781.0507
# epochs = 1200, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 844.6308
# epochs = 1300, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 908.2109
# epochs = 1400, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 971.7910
# epochs = 1500, 기울기1 = 12.5825, 기울기2 = 5.4078, 절편 = 1035.3711
# ...
